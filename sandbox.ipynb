# %%
# Import Libraries
import pandas as pd
import yfinance as yf
import streamlit as st
import os
import datetime
from pandas.tseries.offsets import BDay

pwd = os.getcwd()

# %%
ticker = yf.Ticker("MCD")

# %%
# show next event (earnings, etc)
ticker.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-25 13:30:00  2023-01-30 13:30:00
# Earnings Average                 2.42                 2.42
# Earnings Low                     2.31                 2.31
# Earnings High                     2.6                  2.6
# Revenue Average            5660680000           5660680000
# Revenue Low                5329000000           5329000000
# Revenue High               5911300000           5911300000

# %%
df = ticker.info
df

df = pd.DataFrame()
df

# df = df.melt
# df
# Out:
# {'zip': '60607',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 100000,
#  'longBusinessSummary': "McDonald's Corporation operates and franchises McDonald's restaurants in the United States and internationally. Its restaurants offer hamburgers and cheeseburgers, chicken sandwiches and nuggets, wraps, fries, salads, oatmeal, shakes, desserts, sundaes, soft serve cones, bakery items, soft drinks, coffee, and beverages and other beverages, as well as breakfast menu, including biscuit and bagel sandwiches, breakfast burritos, hotcakes, and other sandwiches. As of December 31, 2021, the company operated 40,031 restaurants. McDonald's Corporation was founded in 1940 and is headquartered in Chicago, Illinois.",
#  'city': 'Chicago',
#  'phone': '630 623 3000',
#  'state': 'IL',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://corporate.mcdonalds.com',
#  'maxAge': 1,
#  'address1': '110 North Carpenter Street',
#  'industry': 'Restaurants',
#  'ebitdaMargins': 0.5182,
#  'profitMargins': 0.25415,
#  'grossMargins': 0.56132,
#  'operatingCashflow': 7851800064,
#  'revenueGrowth': -0.053,
#  'operatingMargins': 0.437,
#  'ebitda': 12056000512,
#  'targetLowPrice': 250,
#  'recommendationKey': 'buy',
#  'grossProfits': 12580200000,
#  'freeCashflow': 4133400064,
#  'targetMedianPrice': 290,
#  'currentPrice': 273.255,
#  'earningsGrowth': -0.063,
#  'currentRatio': 1.647,
#  'returnOnAssets': 0.12554,
#  'numberOfAnalystOpinions': 35,
#  'targetMeanPrice': 288.6,
#  'debtToEquity': None,
#  'returnOnEquity': None,
#  'targetHighPrice': 328,
#  'totalCash': 2828300032,
#  'totalDebt': 47379898368,
#  'totalRevenue': 23265200128,
#  'totalCashPerShare': 3.862,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 31.433,
#  'quickRatio': 1.353,
#  'recommendationMean': 2,
#  'exchange': 'NYQ',
#  'shortName': "McDonald's Corporation",
#  'longName': "McDonald's Corporation",
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MCD',
#  'messageBoardId': 'finmb_139488',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 10.494,
#  'beta3Year': None,
#  'enterpriseToEbitda': 20.251,
#  '52WeekChange': 0.07507491,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.47,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 732424000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': -8.965,
#  'sharesShort': 6079527,
#  'sharesPercentSharesOut': 0.0083,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.70066,
#  'netIncomeToCommon': 5912800256,
#  'trailingEps': 7.93,
#  'lastDividendValue': 1.38,
#  'SandP52WeekChange': -0.15851706,
#  'priceToBook': None,
#  'heldPercentInsiders': 0.0016500001,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1664496000,
#  'shortRatio': 1.84,
#  'sharesShortPreviousMonthDate': 1664496000,
#  'floatShares': 731391174,
#  'beta': 0.647805,
#  'enterpriseValue': 244144439296,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 920851200,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1661904000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.078,
#  'priceToSalesTrailing12Months': 8.602485,
#  'dateShortInterest': 1667174400,
#  'pegRatio': 4.11,
#  'ytdReturn': None,
#  'forwardPE': 26.098854,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0083,
#  'sharesShortPriorMonth': 6751909,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 272.51,
#  'regularMarketOpen': 272.07,
#  'twoHundredDayAverage': 250.6056,
#  'trailingAnnualDividendYield': 0.020256137,
#  'payoutRatio': 0.6961,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 274.3,
#  'navPrice': None,
#  'averageDailyVolume10Day': 3692310,
#  'regularMarketPreviousClose': 272.51,
#  'fiftyDayAverage': 254.6446,
#  'trailingAnnualDividendRate': 5.52,
#  'open': 272.07,
#  'toCurrency': None,
#  'averageVolume10days': 3692310,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 6.08,
#  'exDividendDate': 1669766400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 270.56,
#  'currency': 'USD',
#  'trailingPE': 34.458385,
#  'regularMarketVolume': 989468,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 200138522624,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 2995406,
#  'dayLow': 270.56,
#  'ask': 273.27,
#  'askSize': 1100,
#  'volume': 989468,
#  'fiftyTwoWeekHigh': 281.67,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.3,
#  'fiftyTwoWeekLow': 217.68,
#  'bid': 273.22,
#  'tradeable': False,
#  'dividendYield': 0.0223,
#  'bidSize': 800,
#  'dayHigh': 274.3,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 273.255,
#  'preMarketPrice': 273.33,
#  'logo_url': 'https://logo.clearbit.com/corporate.mcdonalds.com'}
